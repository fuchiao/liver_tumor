# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt

# %%
ROOT = os.getcwd()

# %%
IMG1 = os.path.join(ROOT, 'TrainingBatch1', 'segmentation-15.nii')
img = nib.load(IMG1).get_data()
img.shape
# Out:
# (512, 512, 565)

# %%
plt.figure(figsize=(12,12))
plt.imshow(img[:,:,300])

# %%
IMG2 = os.path.join(ROOT, 'TrainingBatch1', 'volume-15.nii')
img = nib.load(IMG2).get_data()
img.shape
# Out:
# (512, 512, 565)

# %%
plt.figure(figsize=(12,12))
plt.imshow(img[:,:,300])
